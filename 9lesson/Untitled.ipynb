# %%
import json

# %%
f = open('json_data_tfidf.json')

# %%
data = json.load(f)

# %%
data[]
# Out:
# [[0, 10596, 0.07181696388013892],
#  [0, 177, 0.04061792864601968],
#  [0, 8132, 0.06705479966885422],
#  [0, 13718, 0.03692857443086815],
#  [0, 5535, 0.07211431920423234],
#  [0, 22571, 0.11769440075435517],
#  [0, 21736, 0.10208059744328878],
#  [0, 13650, 0.05154893016319347],
#  [0, 19177, 0.018497688209068615],
#  [0, 9286, 0.04993571010382162],
#  [0, 22276, 0.08277653678532623],
#  [0, 15047, 0.09002577553026613],
#  [0, 14690, 0.036250631894890736],
#  [0, 16992, 0.043420444757184117],
#  [0, 17588, 0.1071830763151629],
#  [0, 13220, 0.06335164173790349],
#  [0, 18866, 0.05420583633617701],
#  [0, 6811, 0.09212077507709111],
#  [0, 14529, 0.09002577553026613],
#  [0, 16410, 0.08105794856490425],
#  [0, 13221, 0.06694762865289779],
#  [0, 8438, 0.06591562267863826],
#  [0, 4049, 0.08078954092718148],
#  [0, 9193, 0.09959443863616342],
#  [0, 17583, 0.0802665706323902],
#  [0, 15258, 0.04892660382833785],
#  [0, 4579, 0.07196491271844106],
#  [0, 1667, 0.13158961584499956],
# ...
